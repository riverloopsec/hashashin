# %% [markdown]
# # March 2023 Hashashin Demo

# %%
from hashashin.main import main, get_parser
main(get_parser().parse_args(["--status"]))
# Out:
# Database status:
# 	112 binaries
# 	285841 functions

# %% [markdown]
# ## Minhash Jaccard Similarity Estimation (`--fast-match`)

# %% [markdown]
# ### net-snmp v5.9.2 binaries match with v5.9.3

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/net-snmp/v5.9.2/bin").glob("*")]
main(get_parser().parse_args(["--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmptranslate
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmptranslate: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpset
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpset: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpdelta
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpdelta: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpdf
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpdf: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpstatus
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpstatus: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpusm
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpusm: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpvacm
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpvacm: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/encode_keychange
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/encode_keychange: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/agentxtrap
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/agentxtrap: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpnetstat
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpnetstat: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpgetnext
# INFO:hashashin.main.py:Found 3 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpgetnext: 1.0
# 	binary_data/net-snmp/v5.9.3/bin/snmpget: 0.5360824742268041
# 	binary_data/net-snmp/v5.9.2/bin/snmpget: 0.5360824742268041
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpbulkwalk
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpbulkwalk: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpinform
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpinform: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpget
# INFO:hashashin.main.py:Found 3 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpget: 1.0
# 	binary_data/net-snmp/v5.9.3/bin/snmpgetnext: 0.5416666666666666
# 	binary_data/net-snmp/v5.9.2/bin/snmpgetnext: 0.5416666666666666
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmptable
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmptable: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpbulkget
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpbulkget: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpping
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpping: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmpwalk
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmpwalk: 1.0
#
# INFO:hashashin.main.py:Fast matching target net-snmp/v5.9.2/bin/snmptest
# INFO:hashashin.main.py:Found 1 matches above 0.5 similarity:
# 	binary_data/net-snmp/v5.9.3/bin/snmptest: 1.0

# %% [markdown]
# #### libcurl 7.8

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_8/bin/curl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_8/bin/curl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.11538461538461539

# %% [markdown]
# ### libcurl 7.9.x

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_9*/bin/curl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_9/bin/curl
# INFO:hashashin.main.py:Found 4 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.13592233009708737
# 	binary_data/libcurl/curl-7_51_0/bin/curl: 0.14563106796116504
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 0.1262135922330097
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.10679611650485436
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_9_2/bin/curl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.

# %% [markdown]
# ### libcurl 7.49.x

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_49*/bin/curl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_49_0/bin/curl
# INFO:hashashin.main.py:Found 4 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 0.17346938775510204
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 0.19387755102040816
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.10204081632653061
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.10204081632653061
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_49_1/bin/curl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.

# %% [markdown]
# ### libcurl 7.5x.x

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_5*/bin/curl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_53_1/bin/curl
# INFO:hashashin.main.py:Found 3 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 0.2079207920792079
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.10891089108910891
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.10891089108910891
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_57_0/bin/curl
# INFO:hashashin.main.py:Found 9 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 0.1326530612244898
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 0.15306122448979592
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 0.1836734693877551
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 0.1326530612244898
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 0.10204081632653061
# 	binary_data/net-snmp/v5.9.3/bin/snmpusm: 0.10204081632653061
# 	binary_data/net-snmp/v5.9.2/bin/snmpusm: 0.10204081632653061
# 	binary_data/libcurl/curl-7_8/bin/curl: 0.12244897959183673
# 	binary_data/openssl/openssl-3.0.5/lib/ossl-modules/legacy.so: 0.11224489795918367
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_53_0/bin/curl
# INFO:hashashin.main.py:Found 5 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 0.2079207920792079
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.15841584158415842
# 	binary_data/libcurl/curl-7_51_0/bin/curl: 0.10891089108910891
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.10891089108910891
# 	binary_data/libcurl/curl-7_9/bin/curl: 0.12871287128712872
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_59_0/bin/curl
# INFO:hashashin.main.py:Found 7 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 0.15463917525773196
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.13402061855670103
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 0.10309278350515463
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 0.13402061855670103
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 0.12371134020618557
# 	binary_data/net-snmp/v5.9.3/sbin/snmptrapd: 0.10309278350515463
# 	binary_data/net-snmp/v5.9.2/sbin/snmptrapd: 0.10309278350515463
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_54_0/bin/curl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 0.10204081632653061
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_50_1/bin/curl
# INFO:hashashin.main.py:Found 2 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 0.63
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 0.17
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_54_1/bin/curl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 0.11
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_50_0/bin/curl
# INFO:hashashin.main.py:Found 3 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 0.6363636363636364
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 0.1919191919191919
# 	binary_data/libcurl/curl-7_51_0/bin/curl: 0.15151515151515152
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_55_0/bin/curl
# INFO:hashashin.main.py:Found 6 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_74_0/bin/curl: 0.10101010101010101
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 0.10101010101010101
# 	binary_data/net-snmp/v5.9.3/bin/agentxtrap: 0.10101010101010101
# 	binary_data/net-snmp/v5.9.3/bin/snmpnetstat: 0.10101010101010101
# 	/Users/jonathan.prokos/Documents/Projects/hashashin/hashashin/binary_data/net-snmp/v5.9.2/bin/agentxtrap: 0.10101010101010101
# 	binary_data/net-snmp/v5.9.2/bin/snmpnetstat: 0.10101010101010101
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_55_1/bin/curl
# INFO:hashashin.main.py:Found 7 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_51_0/bin/curl: 0.22
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 0.16
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 0.11
# 	binary_data/libcurl/curl-7_9/bin/curl: 0.14
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 0.12
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.17
# 	binary_data/openssl/openssl-3.0.4/lib/ossl-modules/legacy.so: 0.11
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_51_0/bin/curl
# INFO:hashashin.main.py:Found 5 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 0.15
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.22
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 0.11
# 	binary_data/libcurl/curl-7_9/bin/curl: 0.15
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 0.12
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_52_1/bin/curl
# INFO:hashashin.main.py:Found 2 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 0.27
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 0.12
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_50_2/bin/curl
# INFO:hashashin.main.py:Found 3 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 0.1134020618556701
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 0.12371134020618557
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 0.1134020618556701
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_56_0/bin/curl
# INFO:hashashin.main.py:Found 11 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 0.2222222222222222
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.15151515151515152
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 0.10101010101010101
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 0.13131313131313133
# 	binary_data/net-snmp/v5.9.3/sbin/snmptrapd: 0.12121212121212122
# 	binary_data/net-snmp/v5.9.2/sbin/snmptrapd: 0.12121212121212122
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 0.12121212121212122
# 	binary_data/net-snmp/v5.9.3/bin/snmpdelta: 0.1111111111111111
# 	binary_data/net-snmp/v5.9.2/bin/snmpdelta: 0.1111111111111111
# 	binary_data/net-snmp/v5.9.3/bin/snmpdf: 0.12121212121212122
# 	binary_data/net-snmp/v5.9.2/bin/snmpdf: 0.12121212121212122
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_58_0/bin/curl
# INFO:hashashin.main.py:Found 5 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.1836734693877551
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 0.11224489795918367
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 0.10204081632653061
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 0.14285714285714285
# 	binary_data/libcurl/curl-7_55_0/bin/curl: 0.10204081632653061
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_49_0/bin/curl
# INFO:hashashin.main.py:Found 4 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 0.17346938775510204
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 0.19387755102040816
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 0.10204081632653061
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 0.10204081632653061
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_52_0/bin/curl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 0.27
#
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_56_1/bin/curl
# INFO:hashashin.main.py:Found 8 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 0.2222222222222222
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.13131313131313133
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 0.15151515151515152
# 	binary_data/net-snmp/v5.9.3/sbin/snmptrapd: 0.16161616161616163
# 	binary_data/net-snmp/v5.9.2/sbin/snmptrapd: 0.16161616161616163
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 0.1111111111111111
# 	binary_data/net-snmp/v5.9.3/bin/snmpusm: 0.10101010101010101
# 	binary_data/net-snmp/v5.9.2/bin/snmpusm: 0.10101010101010101

# %% [markdown]
# ### openssl 3.0.x

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/openssl/").glob("openssl-3.0.*/bin/openssl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.1/bin/openssl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.
#
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.0/bin/openssl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.
#
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.5/bin/openssl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.
#
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.2/bin/openssl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/openssl/openssl-3.0.3/lib/ossl-modules/legacy.so: 0.1111111111111111
#
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.3/bin/openssl
# INFO:hashashin.main.py:Found 0 matches above 0.1 similarity.
#
# INFO:hashashin.main.py:Fast matching target openssl/openssl-3.0.4/bin/openssl
# INFO:hashashin.main.py:Found 7 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 0.10344827586206896
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 0.10344827586206896
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 0.10344827586206896
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 0.10344827586206896
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 0.10344827586206896
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 0.11494252873563218
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 0.10344827586206896

# %% [markdown]
# ## Now lets compare to the matrix norm similarity (`--robust-match`)

# %% [markdown]
# ### libcurl 7.8

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_8/bin/curl")]
main(get_parser().parse_args(["--threshold", "0.1", "--fast-match"] + paths))
# Out:
# INFO:hashashin.main.py:Fast matching target libcurl/curl-7_8/bin/curl
# INFO:hashashin.main.py:Found 1 matches above 0.1 similarity:
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 0.11538461538461539

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_8/bin/curl")]
main(get_parser().parse_args(["--robust-match"] + paths))
# Out:
# Collecting target functions: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 34.94it/s]
# INFO:hashashin.main.py:Collecting binaries from database...
# Scoring binaries: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 112/112 [00:50<00:00,  2.20it/s]
# Top 5 scores for libcurl/curl-7_8/bin/curl:
# 	binary_data/libcurl/curl-7_8/bin/curl   : 2.0
# 	binary_data/libcurl/curl-7_9/bin/curl   : 1.9888723503601038
# 	binary_data/libcurl/curl-7_9_2/bin/curl : 1.9852535980067803
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.980910544119431
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9808730060270907

# %% [markdown]
# ### One at a time is slow! Lets do libcurl 7.60 - 7.69 all at the same time

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7_6*/bin/curl")]
main(get_parser().parse_args(["--robust-match"] + paths))
# Out:
# Collecting target functions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:02<00:00,  7.13it/s]
# INFO:hashashin.main.py:Collecting binaries from database...
# Scoring binaries: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 112/112 [02:44<00:00,  1.47s/it]
# Top 5 scores for libcurl/curl-7_66_0/bin/curl:
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9978459881998265
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9976028997278776
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9963963777738518
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.996340064996279
#
# Top 5 scores for libcurl/curl-7_68_0/bin/curl:
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9986478672607726
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9978575538796544
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 1.9976028997278776
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.997566074495023
#
# Top 5 scores for libcurl/curl-7_62_0/bin/curl:
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9987189215989338
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 1.9981886102044273
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9978139244408681
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9970097286695543
#
# Top 5 scores for libcurl/curl-7_65_0/bin/curl:
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9996049082508465
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.998882800972261
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9988784802989739
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.997839711147276
#
# Top 5 scores for libcurl/curl-7_61_1/bin/curl:
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.998175998897952
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9978139244408681
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 1.9976408891274764
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9973172242791493
#
# Top 5 scores for libcurl/curl-7_65_1/bin/curl:
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.9996049082508465
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9989488855556399
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9989229141328955
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.997778175079452
#
# Top 5 scores for libcurl/curl-7_61_0/bin/curl:
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 1.9984012735193488
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.998175998897952
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.9972149818818221
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9970097286695543
#
# Top 5 scores for libcurl/curl-7_64_0/bin/curl:
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9987655391297316
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9981886102044273
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9969530256184957
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9965205545420925
#
# Top 5 scores for libcurl/curl-7_64_1/bin/curl:
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.997839711147276
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.997778175079452
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9972589897581203
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9972573856319988
#
# Top 5 scores for libcurl/curl-7_60_0/bin/curl:
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9984012735193488
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.9982541850206488
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9976408891274764
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9966034054371609
#
# Top 5 scores for libcurl/curl-7_69_1/bin/curl:
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9995761813871948
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9986602634850281
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.997566074495023
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9966760844427307
#
# Top 5 scores for libcurl/curl-7_65_3/bin/curl:
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9999740160033812
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9989488855556399
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.998882800972261
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.9972589897581203
#
# Top 5 scores for libcurl/curl-7_67_0/bin/curl:
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9986478672607726
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 1.9978459881998265
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.997001994910728
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.9966760844427307
#
# Top 5 scores for libcurl/curl-7_63_0/bin/curl:
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 1.9987655391297316
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9987189215989338
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9973172242791493
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9965527314246496
#
# Top 5 scores for libcurl/curl-7_69_0/bin/curl:
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.9995761813871948
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9982445212545408
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9978575538796544
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.997001994910728
#
# Top 5 scores for libcurl/curl-7_65_2/bin/curl:
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9999740160033812
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9989229141328955
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.9988784802989739
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.9972573856319988

# %% [markdown]
# ## How about all of libcurl v7?

# %%
from hashashin.main import main, get_parser
from pathlib import Path
paths = [str(p) for p in Path("binary_data/libcurl/").glob("curl-7*/bin/curl")]
main(get_parser().parse_args(["--robust-match"] + paths))
# Out:
# Collecting target functions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 58/58 [00:07<00:00,  7.73it/s]
# INFO:hashashin.main.py:Collecting binaries from database...
# Scoring binaries: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 112/112 [07:28<00:00,  4.00s/it]
# Top 5 scores for libcurl/curl-7_49_0/bin/curl:
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.9996662815013673
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.99845279357879
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9984504887365273
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9978005761515338
#
# Top 5 scores for libcurl/curl-7_66_0/bin/curl:
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9978459881998265
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9976028997278776
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9963963777738518
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.996340064996279
#
# Top 5 scores for libcurl/curl-7_81_0/bin/curl:
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 1.9987640187758018
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 1.9979655962848328
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 1.9978608481481221
# 	binary_data/libcurl/curl-7_79_1/bin/curl: 1.9975215410031977
#
# Top 5 scores for libcurl/curl-7_49_1/bin/curl:
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.9990143791510953
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9990120190068532
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.9978642698273168
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 1.9978005761515338
#
# Top 5 scores for libcurl/curl-7_68_0/bin/curl:
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9986478672607726
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9978575538796544
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 1.9976028997278776
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.997566074495023
#
# Top 5 scores for libcurl/curl-7_62_0/bin/curl:
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9987189215989338
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 1.9981886102044273
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9978139244408681
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9970097286695543
#
# Top 5 scores for libcurl/curl-7_78_0/bin/curl:
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_79_0/bin/curl: 1.998708181955041
# 	binary_data/libcurl/curl-7_79_1/bin/curl: 1.9986886862215263
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.9984191177261454
# 	binary_data/libcurl/curl-7_76_1/bin/curl: 1.99698960953838
#
# Top 5 scores for libcurl/curl-7_72_0/bin/curl:
# 	binary_data/libcurl/curl-7_72_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 1.998815458358512
# 	binary_data/libcurl/curl-7_71_0/bin/curl: 1.9987237188660807
# 	binary_data/libcurl/curl-7_73_0/bin/curl: 1.997832812169614
# 	binary_data/libcurl/curl-7_74_0/bin/curl: 1.996779909172821
#
# Top 5 scores for libcurl/curl-7_53_1/bin/curl:
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 1.9999308697978173
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9981188331634727
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 1.9978407778063172
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 1.9978079276108778
#
# Top 5 scores for libcurl/curl-7_57_0/bin/curl:
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 1.9988672500106976
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 1.9974279458025368
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 1.9971928614253973
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.9963359754945316
#
# Top 5 scores for libcurl/curl-7_76_1/bin/curl:
# 	binary_data/libcurl/curl-7_76_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_76_0/bin/curl: 1.9996290235101637
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.9980598583648996
# 	binary_data/libcurl/curl-7_75_0/bin/curl: 1.9976737742303903
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 1.99698960953838
#
# Top 5 scores for libcurl/curl-7_53_0/bin/curl:
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 1.9999308697978173
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9980513850396924
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 1.997908208051564
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 1.9978753271787077
#
# Top 5 scores for libcurl/curl-7_59_0/bin/curl:
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 1.9982541850206488
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9972149818818221
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 1.997111391131349
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9967558643655559
#
# Top 5 scores for libcurl/curl-7_76_0/bin/curl:
# 	binary_data/libcurl/curl-7_76_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_76_1/bin/curl: 1.9996290235101637
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.998012301017265
# 	binary_data/libcurl/curl-7_75_0/bin/curl: 1.9978200042233114
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 1.9969559548350182
#
# Top 5 scores for libcurl/curl-7_65_0/bin/curl:
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9996049082508465
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.998882800972261
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9988784802989739
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.997839711147276
#
# Top 5 scores for libcurl/curl-7_82_0/bin/curl:
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9987640187758018
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 1.998400325594465
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 1.9982665377809132
# 	binary_data/libcurl/curl-7_84_0/bin/curl: 1.9970844126857266
#
# Top 5 scores for libcurl/curl-7_61_1/bin/curl:
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.998175998897952
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9978139244408681
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 1.9976408891274764
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9973172242791493
#
# Top 5 scores for libcurl/curl-7_65_1/bin/curl:
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.9996049082508465
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9989488855556399
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9989229141328955
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.997778175079452
#
# Top 5 scores for libcurl/curl-7_61_0/bin/curl:
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 1.9984012735193488
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.998175998897952
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.9972149818818221
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9970097286695543
#
# Top 5 scores for libcurl/curl-7_8/bin/curl:
# 	binary_data/libcurl/curl-7_8/bin/curl   : 2.0
# 	binary_data/libcurl/curl-7_9/bin/curl   : 1.9888723503601038
# 	binary_data/libcurl/curl-7_9_2/bin/curl : 1.9852535980067803
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.980910544119431
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9808730060270907
#
# Top 5 scores for libcurl/curl-7_54_0/bin/curl:
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 1.9981188331634727
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 1.9980513850396924
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 1.9974521756531995
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 1.9971502607413303
#
# Top 5 scores for libcurl/curl-7_50_1/bin/curl:
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.9999976454141173
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9990120190068532
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.9985151000177797
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 1.9984504887365273
#
# Top 5 scores for libcurl/curl-7_71_0/bin/curl:
# 	binary_data/libcurl/curl-7_71_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 1.9999095302866152
# 	binary_data/libcurl/curl-7_72_0/bin/curl: 1.9987237188660807
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9973390073967174
# 	binary_data/libcurl/curl-7_73_0/bin/curl: 1.9968655921745275
#
# Top 5 scores for libcurl/curl-7_75_0/bin/curl:
# 	binary_data/libcurl/curl-7_75_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_76_0/bin/curl: 1.9978200042233114
# 	binary_data/libcurl/curl-7_76_1/bin/curl: 1.9976737742303903
# 	binary_data/libcurl/curl-7_74_0/bin/curl: 1.996848640810862
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.996847701441046
#
# Top 5 scores for libcurl/curl-7_54_1/bin/curl:
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_55_0/bin/curl: 1.9980379216987187
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.997580220320255
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9974521756531995
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 1.9966085276488204
#
# Top 5 scores for libcurl/curl-7_9/bin/curl:
# 	binary_data/libcurl/curl-7_9/bin/curl   : 2.0
# 	binary_data/libcurl/curl-7_8/bin/curl   : 1.9888723503601038
# 	binary_data/libcurl/curl-7_9_2/bin/curl : 1.9888598095663044
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9798769641762912
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.9797029466525902
#
# Top 5 scores for libcurl/curl-7_50_0/bin/curl:
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9999976454141173
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9990143791510953
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.998517406866073
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 1.99845279357879
#
# Top 5 scores for libcurl/curl-7_71_1/bin/curl:
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_71_0/bin/curl: 1.9999095302866152
# 	binary_data/libcurl/curl-7_72_0/bin/curl: 1.998815458358512
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9972477885984934
# 	binary_data/libcurl/curl-7_73_0/bin/curl: 1.9969695199341964
#
# Top 5 scores for libcurl/curl-7_9_2/bin/curl:
# 	binary_data/libcurl/curl-7_9_2/bin/curl : 2.0
# 	binary_data/libcurl/curl-7_9/bin/curl   : 1.9888598095663044
# 	binary_data/libcurl/curl-7_8/bin/curl   : 1.9852535980067803
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.9805360460211836
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9804576182673057
#
# Top 5 scores for libcurl/curl-7_83_0/bin/curl:
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 1.999601557743273
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 1.998400325594465
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9979655962848328
# 	binary_data/libcurl/curl-7_84_0/bin/curl: 1.9979303335528997
#
# Top 5 scores for libcurl/curl-7_64_0/bin/curl:
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 1.9987655391297316
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9981886102044273
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9969530256184957
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9965205545420925
#
# Top 5 scores for libcurl/curl-7_64_1/bin/curl:
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.997839711147276
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.997778175079452
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9972589897581203
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9972573856319988
#
# Top 5 scores for libcurl/curl-7_83_1/bin/curl:
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 1.999601557743273
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 1.9982665377809132
# 	binary_data/libcurl/curl-7_84_0/bin/curl: 1.9980690012577977
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9978608481481221
#
# Top 5 scores for libcurl/curl-7_60_0/bin/curl:
# 	binary_data/libcurl/curl-7_60_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9984012735193488
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.9982541850206488
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9976408891274764
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9966034054371609
#
# Top 5 scores for libcurl/curl-7_55_0/bin/curl:
# 	binary_data/libcurl/curl-7_55_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.999229934017008
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 1.9980379216987187
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9960075517803075
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 1.995796916678492
#
# Top 5 scores for libcurl/curl-7_70_0/bin/curl:
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.9986602634850281
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9982445212545408
# 	binary_data/libcurl/curl-7_71_0/bin/curl: 1.9973390073967174
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 1.9972477885984934
#
# Top 5 scores for libcurl/curl-7_55_1/bin/curl:
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_55_0/bin/curl: 1.999229934017008
# 	binary_data/libcurl/curl-7_54_1/bin/curl: 1.997580220320255
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 1.9962278747389415
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9959092935508633
#
# Top 5 scores for libcurl/curl-7_74_0/bin/curl:
# 	binary_data/libcurl/curl-7_74_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_73_0/bin/curl: 1.9981742327955088
# 	binary_data/libcurl/curl-7_75_0/bin/curl: 1.996848640810862
# 	binary_data/libcurl/curl-7_72_0/bin/curl: 1.996779909172821
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 1.9960202974329566
#
# Top 5 scores for libcurl/curl-7_51_0/bin/curl:
# 	binary_data/libcurl/curl-7_51_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 1.9974174593124796
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.9970985055119432
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.996880087128846
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9968778710508386
#
# Top 5 scores for libcurl/curl-7_69_1/bin/curl:
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.9995761813871948
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9986602634850281
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.997566074495023
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.9966760844427307
#
# Top 5 scores for libcurl/curl-7_65_3/bin/curl:
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 1.9999740160033812
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9989488855556399
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.998882800972261
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.9972589897581203
#
# Top 5 scores for libcurl/curl-7_80_0/bin/curl:
# 	binary_data/libcurl/curl-7_80_0/bin/curl                    : 2.0
# 	binary_data/echo                                            : 1.9920176813372341
# 	binary_data/net-snmp/v5.9.3/bin/snmpbulkwalk                : 1.8770921326119552
# 	binary_data/openssl/openssl-3.0.0/lib/ossl-modules/legacy.so: 1.8611112926262647
# 	binary_data/openssl/openssl-3.0.2/lib/ossl-modules/legacy.so: 1.8604169394214654
#
# Top 5 scores for libcurl/curl-7_67_0/bin/curl:
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9986478672607726
# 	binary_data/libcurl/curl-7_66_0/bin/curl: 1.9978459881998265
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 1.997001994910728
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.9966760844427307
#
# Top 5 scores for libcurl/curl-7_84_0/bin/curl:
# 	binary_data/libcurl/curl-7_84_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_83_1/bin/curl: 1.9980690012577977
# 	binary_data/libcurl/curl-7_83_0/bin/curl: 1.9979303335528997
# 	binary_data/libcurl/curl-7_82_0/bin/curl: 1.9970844126857266
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9968457909910362
#
# Top 5 scores for libcurl/curl-7_63_0/bin/curl:
# 	binary_data/libcurl/curl-7_63_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_64_0/bin/curl: 1.9987655391297316
# 	binary_data/libcurl/curl-7_62_0/bin/curl: 1.9987189215989338
# 	binary_data/libcurl/curl-7_61_1/bin/curl: 1.9973172242791493
# 	binary_data/libcurl/curl-7_61_0/bin/curl: 1.9965527314246496
#
# Top 5 scores for libcurl/curl-7_69_0/bin/curl:
# 	binary_data/libcurl/curl-7_69_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_69_1/bin/curl: 1.9995761813871948
# 	binary_data/libcurl/curl-7_70_0/bin/curl: 1.9982445212545408
# 	binary_data/libcurl/curl-7_68_0/bin/curl: 1.9978575538796544
# 	binary_data/libcurl/curl-7_67_0/bin/curl: 1.997001994910728
#
# Top 5 scores for libcurl/curl-7_65_2/bin/curl:
# 	binary_data/libcurl/curl-7_65_2/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_65_3/bin/curl: 1.9999740160033812
# 	binary_data/libcurl/curl-7_65_1/bin/curl: 1.9989229141328955
# 	binary_data/libcurl/curl-7_65_0/bin/curl: 1.9988784802989739
# 	binary_data/libcurl/curl-7_64_1/bin/curl: 1.9972573856319988
#
# Top 5 scores for libcurl/curl-7_52_1/bin/curl:
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 1.999967327131221
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 1.997908208051564
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 1.9978407778063172
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9971502607413303
#
# Top 5 scores for libcurl/curl-7_73_0/bin/curl:
# 	binary_data/libcurl/curl-7_73_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_74_0/bin/curl: 1.9981742327955088
# 	binary_data/libcurl/curl-7_72_0/bin/curl: 1.997832812169614
# 	binary_data/libcurl/curl-7_71_1/bin/curl: 1.9969695199341964
# 	binary_data/libcurl/curl-7_71_0/bin/curl: 1.9968655921745275
#
# Top 5 scores for libcurl/curl-7_79_0/bin/curl:
# 	binary_data/libcurl/curl-7_79_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_79_1/bin/curl: 1.9999805472423595
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 1.998708181955041
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9975019981624413
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.9974204376161686
#
# Top 5 scores for libcurl/curl-7_50_2/bin/curl:
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 1.9996662815013673
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.998517406866073
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9985151000177797
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9978642698273168
#
# Top 5 scores for libcurl/curl-7_56_0/bin/curl:
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 1.9993007536925216
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 1.9971928614253973
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 1.9967450105958662
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.9962278747389415
#
# Top 5 scores for libcurl/curl-7_79_1/bin/curl:
# 	binary_data/libcurl/curl-7_79_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_79_0/bin/curl: 1.9999805472423595
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 1.9986886862215263
# 	binary_data/libcurl/curl-7_81_0/bin/curl: 1.9975215410031977
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 1.9973995984674169
#
# Top 5 scores for libcurl/curl-7_58_0/bin/curl:
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 1.9988672500106976
# 	binary_data/libcurl/curl-7_59_0/bin/curl: 1.997111391131349
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 1.9970526258486356
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 1.9967450105958662
#
# Top 5 scores for libcurl/curl-7_49_0/bin/curl:
# 	binary_data/libcurl/curl-7_49_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_50_2/bin/curl: 1.9996662815013673
# 	binary_data/libcurl/curl-7_50_0/bin/curl: 1.99845279357879
# 	binary_data/libcurl/curl-7_50_1/bin/curl: 1.9984504887365273
# 	binary_data/libcurl/curl-7_49_1/bin/curl: 1.9978005761515338
#
# Top 5 scores for libcurl/curl-7_52_0/bin/curl:
# 	binary_data/libcurl/curl-7_52_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_52_1/bin/curl: 1.999967327131221
# 	binary_data/libcurl/curl-7_53_0/bin/curl: 1.9978753271787077
# 	binary_data/libcurl/curl-7_53_1/bin/curl: 1.9978079276108778
# 	binary_data/libcurl/curl-7_54_0/bin/curl: 1.9971127388696512
#
# Top 5 scores for libcurl/curl-7_77_0/bin/curl:
# 	binary_data/libcurl/curl-7_77_0/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_78_0/bin/curl: 1.9984191177261454
# 	binary_data/libcurl/curl-7_76_1/bin/curl: 1.9980598583648996
# 	binary_data/libcurl/curl-7_76_0/bin/curl: 1.998012301017265
# 	binary_data/libcurl/curl-7_79_0/bin/curl: 1.9974204376161686
#
# Top 5 scores for libcurl/curl-7_56_1/bin/curl:
# 	binary_data/libcurl/curl-7_56_1/bin/curl: 2.0
# 	binary_data/libcurl/curl-7_56_0/bin/curl: 1.9993007536925216
# 	binary_data/libcurl/curl-7_57_0/bin/curl: 1.9974279458025368
# 	binary_data/libcurl/curl-7_58_0/bin/curl: 1.9970526258486356
# 	binary_data/libcurl/curl-7_55_1/bin/curl: 1.9958417445134862

# %% [markdown]
# ## Let's plot this

# %%
from hashashin.main import ApplicationFactory, HashashinApplicationContext
from hashashin.classes import BinjaFeatureExtractor
from hashashin.db import HashRepository
app_context = HashashinApplicationContext(
                extractor=BinjaFeatureExtractor(),
                hash_repo=HashRepository(),
                target_path=None,
                save_to_db=False
            )
hashApp = ApplicationFactory.getHasher(app_context)

# %%
from hashashin.metrics import generate_matrix_norms
norms, binaries = generate_matrix_norms("libcurl", hashApp, paths="*[0-9]_[0-9]*")
# Out:
# INFO:hashashin.metrics.py:Computing signatures for [PosixPath('binary_data/libcurl/curl-7_49_0'), PosixPath('binary_data/libcurl/curl-7_66_0'), PosixPath('binary_data/libcurl/curl-7_81_0'), PosixPath('binary_data/libcurl/curl-7_9_1'), PosixPath('binary_data/libcurl/curl-7_49_1'), PosixPath('binary_data/libcurl/curl-7_68_0'), PosixPath('binary_data/libcurl/curl-7_62_0'), PosixPath('binary_data/libcurl/curl-7_78_0'), PosixPath('binary_data/libcurl/curl-7_72_0'), PosixPath('binary_data/libcurl/curl-7_53_1'), PosixPath('binary_data/libcurl/curl-7_57_0'), PosixPath('binary_data/libcurl/curl-7_76_1'), PosixPath('binary_data/libcurl/curl-7_53_0'), PosixPath('binary_data/libcurl/curl-7_59_0'), PosixPath('binary_data/libcurl/curl-7_76_0'), PosixPath('binary_data/libcurl/curl-7_65_0'), PosixPath('binary_data/libcurl/curl-7_82_0'), PosixPath('binary_data/libcurl/curl-7_61_1'), PosixPath('binary_data/libcurl/curl-7_65_1'), PosixPath('binary_data/libcurl/curl-7_61_0'), PosixPath('binary_data/libcurl/curl-7_8'), PosixPath('binary_data/libcurl/curl-7_54_0'), PosixPath('binary_data/libcurl/curl-7_50_1'), PosixPath('binary_data/libcurl/curl-7_71_0'), PosixPath('binary_data/libcurl/curl-7_75_0'), PosixPath('binary_data/libcurl/curl-7_54_1'), PosixPath('binary_data/libcurl/curl-7_9'), PosixPath('binary_data/libcurl/curl-7_50_0'), PosixPath('binary_data/libcurl/curl-7_71_1'), PosixPath('binary_data/libcurl/curl-7_9_2'), PosixPath('binary_data/libcurl/curl-7_83_0'), PosixPath('binary_data/libcurl/curl-7_64_0'), PosixPath('binary_data/libcurl/curl-7_64_1'), PosixPath('binary_data/libcurl/curl-7_83_1'), PosixPath('binary_data/libcurl/curl-7_60_0'), PosixPath('binary_data/libcurl/curl-7_55_0'), PosixPath('binary_data/libcurl/curl-7_70_0'), PosixPath('binary_data/libcurl/curl-7_55_1'), PosixPath('binary_data/libcurl/curl-7_74_0'), PosixPath('binary_data/libcurl/curl-7_51_0'), PosixPath('binary_data/libcurl/curl-7_69_1'), PosixPath('binary_data/libcurl/curl-7_65_3'), PosixPath('binary_data/libcurl/curl-7_8_1'), PosixPath('binary_data/libcurl/curl-7_80_0'), PosixPath('binary_data/libcurl/curl-7_67_0'), PosixPath('binary_data/libcurl/curl-7_84_0'), PosixPath('binary_data/libcurl/curl-7_63_0'), PosixPath('binary_data/libcurl/curl-7_69_0'), PosixPath('binary_data/libcurl/curl-7_65_2'), PosixPath('binary_data/libcurl/curl-7_52_1'), PosixPath('binary_data/libcurl/curl-7_73_0'), PosixPath('binary_data/libcurl/curl-7_79_0'), PosixPath('binary_data/libcurl/curl-7_50_2'), PosixPath('binary_data/libcurl/curl-7_56_0'), PosixPath('binary_data/libcurl/curl-7_79_1'), PosixPath('binary_data/libcurl/curl-7_58_0'), PosixPath('binary_data/libcurl/curl-7_50_3'), PosixPath('binary_data/libcurl/curl-7_52_0'), PosixPath('binary_data/libcurl/curl-7_77_0'), PosixPath('binary_data/libcurl/curl-7_56_1')]..
# INFO:hashashin.main.py:Hashing [PosixPath('binary_data/libcurl/curl-7_49_0'), PosixPath('binary_data/libcurl/curl-7_66_0'), PosixPath('binary_data/libcurl/curl-7_81_0'), PosixPath('binary_data/libcurl/curl-7_9_1'), PosixPath('binary_data/libcurl/curl-7_49_1'), PosixPath('binary_data/libcurl/curl-7_68_0'), PosixPath('binary_data/libcurl/curl-7_62_0'), PosixPath('binary_data/libcurl/curl-7_78_0'), PosixPath('binary_data/libcurl/curl-7_72_0'), PosixPath('binary_data/libcurl/curl-7_53_1'), PosixPath('binary_data/libcurl/curl-7_57_0'), PosixPath('binary_data/libcurl/curl-7_76_1'), PosixPath('binary_data/libcurl/curl-7_53_0'), PosixPath('binary_data/libcurl/curl-7_59_0'), PosixPath('binary_data/libcurl/curl-7_76_0'), PosixPath('binary_data/libcurl/curl-7_65_0'), PosixPath('binary_data/libcurl/curl-7_82_0'), PosixPath('binary_data/libcurl/curl-7_61_1'), PosixPath('binary_data/libcurl/curl-7_65_1'), PosixPath('binary_data/libcurl/curl-7_61_0'), PosixPath('binary_data/libcurl/curl-7_8'), PosixPath('binary_data/libcurl/curl-7_54_0'), PosixPath('binary_data/libcurl/curl-7_50_1'), PosixPath('binary_data/libcurl/curl-7_71_0'), PosixPath('binary_data/libcurl/curl-7_75_0'), PosixPath('binary_data/libcurl/curl-7_54_1'), PosixPath('binary_data/libcurl/curl-7_9'), PosixPath('binary_data/libcurl/curl-7_50_0'), PosixPath('binary_data/libcurl/curl-7_71_1'), PosixPath('binary_data/libcurl/curl-7_9_2'), PosixPath('binary_data/libcurl/curl-7_83_0'), PosixPath('binary_data/libcurl/curl-7_64_0'), PosixPath('binary_data/libcurl/curl-7_64_1'), PosixPath('binary_data/libcurl/curl-7_83_1'), PosixPath('binary_data/libcurl/curl-7_60_0'), PosixPath('binary_data/libcurl/curl-7_55_0'), PosixPath('binary_data/libcurl/curl-7_70_0'), PosixPath('binary_data/libcurl/curl-7_55_1'), PosixPath('binary_data/libcurl/curl-7_74_0'), PosixPath('binary_data/libcurl/curl-7_51_0'), PosixPath('binary_data/libcurl/curl-7_69_1'), PosixPath('binary_data/libcurl/curl-7_65_3'), PosixPath('binary_data/libcurl/curl-7_8_1'), PosixPath('binary_data/libcurl/curl-7_80_0'), PosixPath('binary_data/libcurl/curl-7_67_0'), PosixPath('binary_data/libcurl/curl-7_84_0'), PosixPath('binary_data/libcurl/curl-7_63_0'), PosixPath('binary_data/libcurl/curl-7_69_0'), PosixPath('binary_data/libcurl/curl-7_65_2'), PosixPath('binary_data/libcurl/curl-7_52_1'), PosixPath('binary_data/libcurl/curl-7_73_0'), PosixPath('binary_data/libcurl/curl-7_79_0'), PosixPath('binary_data/libcurl/curl-7_50_2'), PosixPath('binary_data/libcurl/curl-7_56_0'), PosixPath('binary_data/libcurl/curl-7_79_1'), PosixPath('binary_data/libcurl/curl-7_58_0'), PosixPath('binary_data/libcurl/curl-7_50_3'), PosixPath('binary_data/libcurl/curl-7_52_0'), PosixPath('binary_data/libcurl/curl-7_77_0'), PosixPath('binary_data/libcurl/curl-7_56_1')]
# INFO:hashashin.main.py:Hashing 58 binaries
# Globbing binary_data/libcurl/*[0-9]_[0-9]*
# INFO:hashashin.metrics.py:Done computing signatures.
# INFO:hashashin.metrics.py:Converting signatures to function matrices..
# Computing norms: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3364/3364 [01:15<00:00, 44.46it/s]
# INFO:hashashin.metrics.py:Precision: 0.5, Recall: 1.0, F1: 0.6666666666666666

# %% [markdown]
# ## That plot isn't very useful... lets rescale it

# %%
from hashashin.metrics import show_similarity_matrix
show_similarity_matrix((norms - 1) ** 100, binaries, "libcurl", font_scale=0.6, figsize=(20, 20))

# %% [markdown]
# # Lets do this for openssl!

# %%
from hashashin.main import ApplicationFactory, HashashinApplicationContext
from hashashin.classes import BinjaFeatureExtractor
from hashashin.db import HashRepository
from hashashin.metrics import generate_matrix_norms
app_context = HashashinApplicationContext(
                extractor=BinjaFeatureExtractor(),
                hash_repo=HashRepository(),
                target_path=None,
                save_to_db=False
            )
hashApp = ApplicationFactory.getHasher(app_context)
norms, binaries = generate_matrix_norms("openssl", hashApp, paths="*[0-9].[0-9]*", rescale=lambda norm: (norm - 1) ** 100)
# Out:
# INFO:hashashin.metrics.py:Computing signatures for [PosixPath('binary_data/openssl/openssl-3.0.1'), PosixPath('binary_data/openssl/openssl-3.0.0'), PosixPath('binary_data/openssl/openssl-3.0.5'), PosixPath('binary_data/openssl/openssl-3.0.2'), PosixPath('binary_data/openssl/openssl-3.0.3'), PosixPath('binary_data/openssl/openssl-3.0.4')]..
# INFO:hashashin.main.py:Hashing [PosixPath('binary_data/openssl/openssl-3.0.1'), PosixPath('binary_data/openssl/openssl-3.0.0'), PosixPath('binary_data/openssl/openssl-3.0.5'), PosixPath('binary_data/openssl/openssl-3.0.2'), PosixPath('binary_data/openssl/openssl-3.0.3'), PosixPath('binary_data/openssl/openssl-3.0.4')]
# Globbing binary_data/openssl/*[0-9].[0-9]*
# INFO:hashashin.main.py:Hashing 42 binaries
#
# Extracting binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.1/share/man/man3/OSSL_SELF_TEST_free.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.0/share/man/man3/OSSL_SELF_TEST_free.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.5/share/man/man3/OSSL_SELF_TEST_free.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.2/share/man/man3/OSSL_SELF_TEST_free.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
# Extracting binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.3/share/man/man3/OSSL_SELF_TEST_free.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl: 0it [00:00, ?it/s]
#                                                                                                                    INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_oncorrupt_byte.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl: 0it [00:00, ?it/s]
#                                                                                                                  INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_get_callback.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl: 0it [00:00, ?it/s]
#                                                                                                             INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_onbegin.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_onend.3ossl: 0it [00:00, ?it/s]
#                                                                                                           INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_onend.3ossl
#
# Extracting binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_free.3ossl: 0it [00:00, ?it/s]
#                                                                                                          INFO:hashashin.main.py:Skipping non-binary binary_data/openssl/openssl-3.0.4/share/man/man3/OSSL_SELF_TEST_free.3ossl
# INFO:hashashin.metrics.py:Done computing signatures.
# INFO:hashashin.metrics.py:Converting signatures to function matrices..
# Computing norms: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 144/144 [01:23<00:00,  1.72it/s]
# INFO:hashashin.metrics.py:Precision: 0.5, Recall: 1.0, F1: 0.6666666666666666

# %%
from hashashin.main import ApplicationFactory, HashashinApplicationContext
from hashashin.classes import BinjaFeatureExtractor
from hashashin.db import HashRepository
from hashashin.metrics import generate_matrix_norms
app_context = HashashinApplicationContext(
                extractor=BinjaFeatureExtractor(),
                hash_repo=HashRepository(),
                target_path=None,
                save_to_db=False
            )
hashApp = ApplicationFactory.getHasher(app_context)
norms, binaries = generate_matrix_norms("openssl", hashApp, paths="*[0-9].[0-9]*/bin/openssl", rescale=lambda norm: (norm - 1) ** 100)
# Out:
# INFO:hashashin.metrics.py:Computing signatures for [PosixPath('binary_data/openssl/openssl-3.0.1/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.0/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.5/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.2/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.3/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.4/bin/openssl')]..
# INFO:hashashin.main.py:Hashing [PosixPath('binary_data/openssl/openssl-3.0.1/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.0/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.5/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.2/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.3/bin/openssl'), PosixPath('binary_data/openssl/openssl-3.0.4/bin/openssl')]
# INFO:hashashin.main.py:Hashing 6 binaries
# Globbing binary_data/openssl/*[0-9].[0-9]*/bin/openssl
# INFO:hashashin.metrics.py:Done computing signatures.
# INFO:hashashin.metrics.py:Converting signatures to function matrices..
# Computing norms: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:28<00:00,  1.27it/s]
# INFO:hashashin.metrics.py:Precision: 0.5, Recall: 1.0, F1: 0.6666666666666666

# %%
from hashashin.main import ApplicationFactory, HashashinApplicationContext
from hashashin.classes import BinjaFeatureExtractor
from hashashin.db import HashRepository
from hashashin.metrics import generate_matrix_norms
app_context = HashashinApplicationContext(
                extractor=BinjaFeatureExtractor(),
                hash_repo=HashRepository(),
                target_path=None,
                save_to_db=False
            )
hashApp = ApplicationFactory.getHasher(app_context)
norms, binaries = generate_matrix_norms("openssl", hashApp, paths="*[0-9].[0-9]*/lib/ossl-modules/legacy.so", rescale=lambda norm: (norm - 1) ** 100)
# Out:
# INFO:hashashin.metrics.py:Computing signatures for [PosixPath('binary_data/openssl/openssl-3.0.1/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.0/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.5/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.2/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.3/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.4/lib/ossl-modules/legacy.so')]..
# INFO:hashashin.main.py:Hashing [PosixPath('binary_data/openssl/openssl-3.0.1/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.0/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.5/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.2/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.3/lib/ossl-modules/legacy.so'), PosixPath('binary_data/openssl/openssl-3.0.4/lib/ossl-modules/legacy.so')]
# INFO:hashashin.main.py:Hashing 6 binaries
# Globbing binary_data/openssl/*[0-9].[0-9]*/lib/ossl-modules/legacy.so
# INFO:hashashin.metrics.py:Done computing signatures.
# INFO:hashashin.metrics.py:Converting signatures to function matrices..
# Computing norms: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:15<00:00,  2.35it/s]
# INFO:hashashin.metrics.py:Precision: 0.5, Recall: 1.0, F1: 0.6666666666666666
